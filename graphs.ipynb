# %% [markdown]
# ### Total attacks and average attacks

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
beta = [25, 50, 90, 100]
# Cars
# total_attacks = [92, 390, 600, 780]
# avg_att_prefer = [0.14, 0.46, 0.70, 0.93]

# Myocardial
# total_attacks = [199, 503, 561, 1007]
# avg_att_prefer = [0.08, 0.21, 0.37, 0.43]

# Cirrhosis
# total_attacks = [630, 2209, 3616, 4418]
# avg_att_prefer = [0.20, 0.89, 1.55, 1.79]

# Soccer
total_attacks = [86, 216, 373, 432]
avg_att_prefer = [0.13, 0.41, 0.65, 0.82]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the single line
ax.plot(beta, avg_att_prefer, marker='o', label="Avg. activated att.", linewidth=2)

# Add labels to the points
for j, value in enumerate(avg_att_prefer):
    ax.text(beta[j] - 2, value + 0.03, f'{value:.2f}', ha='center', fontsize=18)

# Customize x-axis ticks
ax.set_xticks(beta)
new_labels = [f'{tatt} ({b})' for b, tatt in zip(beta, total_attacks)]
ax.set_xticklabels(new_labels, fontsize=16, rotation=20)

# Axis limits
ax.set_ylim(0, 1.1)
ax.set_xlim(min(beta) - 6, max(beta) + 2)

# Labels and title
ax.set_xlabel(r'Total attacks ($\beta$)', fontsize=19)
ax.set_ylabel("Avg. activated attacks", fontsize=18)
ax.set_title("(a) Avg activated att. per semantic and " + r"$\beta$" + " values", fontsize=24, pad=20)

# Legend and grid
ax.legend(fontsize=16)
ax.grid(True, linestyle='--', alpha=0.4)

# Final layout and save
plt.tight_layout()
plt.savefig("total_attacks.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Fidelity, NAs and kappa

# %%
import matplotlib.pyplot as plt
import numpy as np

# Labels and data
labels = ['Pref. (β=25)', 'Pref. (β=50)', 'Pref. (β=90)', 'Pref. (β=100)',
          'Categ. (β=25)', 'Categ. (β=50)', 'Categ. (β=90)', 'Categ. (β=100)',
          'Ground. (β=25)', 'Ground. (β=50)', 'Ground. (β=90)', 'Ground. (β=100)'][::-1]
# Cars
# kappa_values = [0.94, 0.84, 0.88, 0.99, 0.94, 0.84, 0.88, 0.99, 0.75, 0.84, 0.88, 0.99][::-1]
# na_values    = [0.11, 0.00, 0.11, 0.18, 0.11, 0.00, 0.11, 0.18, 0.00, 0.02, 0.11, 0.20][::-1]
# #fidelity_values = [0.97, 0.92, 0.96, 0.99, 0.97, 0.92, 0.96, 0.99, 0.97, 0.92, 0.96, 0.99][::-1]
# fidelity_values = [0.999, 0.994, 0.993, 0.999, 0.999, 1.0, 0.998, 0.999, 0.912, 0.994, 0.993, 1.0][::-1]

# print(sum(fidelity_values) / len(fidelity_values))
# mcnemar = ["-", 0.00, 0.00, "-", "-", "-", "-", "-", 0, 0, 0, "-"][::-1]

# Myocardial
# kappa_values = [0.53, 0.51, 0.54, 0.55, 0.52, 0.50, 0.53, 0.54, 0.54, 0.53, 0.54, 0.54][::-1]
# na_values = [0.45, 0.42, 0.47, 0.48, 0.45, 0.42, 0.46, 0.46, 0.42, 0.42, 0.47, 0.48][::-1]
# # fidelity_values = [0.85, 0.83, 0.87, 0.88, 0.86, 0.83, 0.86, 0.87, 0.84, 0.84, 0.88, 0.88][::-1]
# fidelity_values = [0.999, 0.999, 1, 1, 0.999, 1, 0.982, 0.984, 0.961, 0.999, 1.0, 1.0][::-1]
# print(sum(fidelity_values) / len(fidelity_values))
# mcnemar = ["-", "-", "-", "-", "-", "-", 0.28, 0.72, 0.055, "-", "-", "-"][::-1]

# Cirrhosis
# kappa_values = [0.90, 0.79, 0.91, 0.96, 0.92, 0.82, 0.92, 0.95, 0.76, 0.79, 0.93, 1.00][::-1]
# na_values = [0.15, 0.01, 0.16, 0.20, 0.17, 0.04, 0.15, 0.19, 0.01, 0.01, 0.22, 0.29][::-1]
# # fidelity_values = [0.93, 0.87, 0.93, 0.96, 0.94, 0.88, 0.92, 0.95, 0.87, 0.87, 0.96, 1.00][::-1]
# fidelity_values = [0.988, 0.977, 0.979, 0.981, 0.991, 1.0, 0.979, 0.978, 0.884, 0.977, 0.994, 1.00][::-1]
# print(sum(fidelity_values) / len(fidelity_values))
# mcnemar = [0.61, 0.04, 0.45, 0.22, "-", "-", 0.02, 0.13, 0.03, 0.04, 0.04, "-"][::-1]


# Soccer
kappa_values = [0.35, 0.32, 0.33, 0.36, 0.35, 0.33, 0.33, 0.36, 0.31, 0.32, 0.33, 0.36][::-1]
na_values = [0.43, 0.35, 0.43, 0.48, 0.43, 0.35, 0.42, 0.47, 0.35, 0.35, 0.44, 0.50][::-1]
# fidelity_values = [0.58, 0.56, 0.56, 0.58, 0.58, 0.55, 0.56, 0.58, 0.56, 0.56, 0.56, 0.58][::-1]
fidelity_values = [0.99, 0.984, 0.986, 0.99, 0.991, 0.989, 0.978, 0.973, 0.897, 0.984, 0.987, 0.991][::-1]
print(sum(fidelity_values) / len(fidelity_values))
mcnemar = [0.09, 0.03, 0.09, 0.26, 0.14, 0.21, 0.04, 0.85, 1.0, 0.03, 0.08, 0.22][::-1]


# Introduce vertical gap by adjusting y_pos
gap = 1  # Vertical gap between every 4 rows
y_pos = np.arange(len(labels)) + (np.floor(np.arange(len(labels)) / 4) * gap)

bar_height = 0.8

fig, ax = plt.subplots(figsize=(10, 8))  # Adjust figure size for readability

# NA (orange) bars to the left
bars_na = ax.barh(y_pos, [-v for v in na_values], height=bar_height,
                  color='#ff7f0e', edgecolor='black', label='NAs (lower is better)')

# κ (blue) bars to the right
bars_kappa = ax.barh(y_pos, kappa_values, height=bar_height,
                     color='#1f77b4', edgecolor='black', label='κ (higher is better)')

# Add value labels with larger font size
for i in range(len(labels)):
    ax.text(-na_values[i] - 0.02, y_pos[i], f' {na_values[i]:.2f}', va='center', ha='right', fontsize=18)
    ax.text(kappa_values[i] + 0.02, y_pos[i], f' {kappa_values[i]:.2f}', va='center', ha='left', fontsize=18)

x_vals = [-v for v in fidelity_values]  # Negative because NA bars go to the left

# Draw a single connected red line through all the points
ax.plot(x_vals, y_pos, color='red', linewidth=2.5, label='Fidelity (McNemar\'s p-value)')

# Optionally, add a red dot + label for each point
for x, y, val, x_mcnemar in zip(x_vals, y_pos, fidelity_values, mcnemar):
    ax.plot(x, y, 'o', color='red', markersize=6)
    

    try:
        ax.text(x - 0.10, y, f'{val:.3f} ({x_mcnemar:.2f})', va='center', ha='right', fontsize=16, color='red')

        #ax.text(x - 0.05, y, f'({x_mcnemar:.2f})', va='center', ha='right', fontsize=16, color='red')    
    except:
        ax.text(x - 0.10, y, f'{val:.3f} ({x_mcnemar})', va='center', ha='right', fontsize=16, color='red')

        #ax.text(x - 0.05, y, f'({x_mcnemar:>})', va='center', ha='right', fontsize=16, color='red')

# Customize axes with larger font sizes
ax.set_yticks(y_pos)
ax.set_yticklabels(labels, fontsize=22)
ax.axvline(0, color='black', linewidth=1.2)

# ax.axvline(0.85, color='gray', linestyle='--', linewidth=2.5, label='LLM1 κ (0.85)')
# ax.axvline(0.50, color='gray', linestyle='--', linewidth=2.5, label='LLM2 κ (0.50) and NA (0.42)')
# ax.axvline(-0.42, color='gray', linestyle='--', linewidth=2.5)
# ax.axvline(0.81, color='gray', linestyle='--', linewidth=2.5, label='LLM3 κ (0.81)')
ax.axvline(0.34, color='gray', linestyle='--', linewidth=2.5, label='LLM4 κ (0.34) and NA (0.33)')
ax.axvline(-0.33, color='gray', linestyle='--', linewidth=2.5)


# ax.set_xlabel("Fidelity and deviations from LLM1 (κ=0.85, NA=0.0)", fontsize=19)
# ax.set_title("(b) κ, NAs, and fidelity relative to LLM1", fontsize=24, pad=80)

# ax.set_xlabel("Fidelity and deviations from LLM2 (κ=0.50, NA=0.42)", fontsize=19)
# ax.set_title("(b) κ, NAs, and fidelity relative to LLM2", fontsize=24, pad=80)

# ax.set_xlabel("Fidelity and deviations from LLM3 (κ=0.81, NA=0.0)", fontsize=19)
# ax.set_title("(b) κ, NAs, and fidelity relative to LLM3", fontsize=24, pad=80)

ax.set_xlabel("Fidelity and deviations from LLM4 (κ=0.34, NA=0.33)", fontsize=19)
ax.set_title("(b) κ, NAs, and fidelity relative to LLM4", fontsize=24, pad=80)

# ax.grid(True, axis='x', linestyle='--', alpha=0.4)
ax.grid(True, axis='x', linestyle='--', alpha=0.5)

# Symmetric x-axis
ax.set_xlim(-1.75, max(kappa_values) + 0.30)
# ax.set_xlim(-0.75, max(kappa_values) + 0.30)
xticks = ax.get_xticks()
ax.set_xticklabels([f'{abs(tick):.2f}' for tick in xticks], fontsize=12)

ax.tick_params(axis='x', labelsize=16)  # Increase font size for x-axis ticks

# Legend with larger font
#ax.legend(loc=0, fontsize=14)  # Bottom-left of the figure
ax.legend(
    loc='upper center',
    bbox_to_anchor=(0.51, 1.15),   # Centered and placed just below the title
    fontsize=15,
    frameon=True,
    ncol=2                        # One row with two items side by side
)

plt.tight_layout()
plt.savefig("k_and_nas.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0.9783333333333334
# C:\Users\Work\AppData\Local\Temp\ipykernel_11356\2631651532.py:115: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([f'{abs(tick):.2f}' for tick in xticks], fontsize=12)

# %% [markdown]
# ### Merge the two images

# %%
from PIL import Image

# Open the two images
image1 = Image.open("total_attacks.png")
image2 = Image.open("k_and_nas.png")

# Get the dimensions of both images
width1, height1 = image1.size
width2, height2 = image2.size

# Define the gap size
gap = 100

# Create a new image with the combined height and the maximum width of both images + gap
new_width = max(width1, width2)
new_height = height1 + gap + height2

# Create a new blank image with the desired size and white background
new_image = Image.new("RGB", (new_width, new_height), color="white")

# Paste the images one on top of the other with a gap in between
new_image.paste(image1, (0, 0))                    # Paste image1 at the top-left corner
new_image.paste(image2, (0, height1 + gap))        # Paste image2 below image1, with gap

# Save the new merged image
# new_image.save("soccer_dataset.png")
# new_image.save("cars.png")
# new_image.save("myocardial.png")
# new_image.save("cirrohosis.png")
new_image.save("soccer.png")

# Optionally, display the merged image
new_image.show()
